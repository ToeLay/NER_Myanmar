# %%
__author__      = 'Roy Gardner'
__copyright__   = 'Copyright 2021, Ontonomic'

import json
import os
import csv
from termcolor import colored 

import textract
import spacy
from spacy.lang.en import English
        
def process(file_dir,nlp):
    """
    Do the work
    """
    document_dict = {}
    sentence_dict = {}

    _, _, files = next(os.walk(file_dir))
    
    file_list = sorted([file_dir + f for f in files if not f[0] == '.'])
    word_length = 3
    for n,file in enumerate(file_list):
        try:
            # Get the text from the file
            text = textract.process(file).decode('utf-8')
            doc_id = str(n)
            base=os.path.basename(file)
            doc_title = os.path.splitext(base)[0]
            document_dict[doc_id] = {}
            document_dict[doc_id]['name'] = doc_title
            
            # Create a spaCy doc object
            doc = nlp(text)
            sentence_list = []
            
            for i,sent in enumerate(doc.sents):
                sentence_id = doc_id + '/' + str(i)
                sentence_dict[sentence_id] = sent.text
        except:
            print('Error processing:',doc_title)
    return document_dict,sentence_dict

        
# Using basic spaCy model for sentence segmentation
nlp_en = English()  
sentencizer = nlp_en.add_pipe('sentencizer')
sentencizer.punct_chars.add(';')

# %%
doc_directory = './docs/'

regex = u'[,]\s+(?=[A-Z])' # For COP docs
#regex = '' # For other docs

document_dict,sentence_dict = process(doc_directory,nlp_en)

# Serialise the dictionaries for later use
filename = './serialised/document_dict.json'
with open(filename, 'w') as f:
    json.dump(document_dict, f)
    f.close()
filename = './serialised/sentence_dict.json'
with open(filename, 'w') as f:
    json.dump(sentence_dict, f)
    f.close()

# Generate CSVs containing the sentences - one per doc
selected_docs = list(document_dict.keys())
for i,doc_id in enumerate(selected_docs):
    csv_data = []
    csv_data.append(['Sentence number','Sentence text'])

    for k,v in sentence_dict.items():

        d_id = k.split('/')[0] 
        s_id = k.split('/')[1] 

        if d_id == doc_id:
            csv_row = []
            csv_row.append(s_id)
            csv_row.append(v)
            csv_data.append(csv_row)
            #print(n,k,v)
        else:
            n = 0

    with open('./segmented_documents/' + document_dict[doc_id]['name'] + '.csv', 'w', encoding="utf-8", newline='') as outfile:
        writer = csv.writer(outfile)
        writer.writerows(csv_data)
    outfile.close()
    
print('Finished')
# Out:
# Finished

# %%
print(colored('Number of documents','blue'),len(document_dict))
print(colored('Number of sentences','blue'),len(sentence_dict))
print('')

# Accessing data

# Name of first doc
doc_id = list(document_dict.keys())[0]
print(doc_id,document_dict[doc_id]['name'])
print('')

# Text of sentence
sentence_id = list(sentence_dict.keys())[10]
print(sentence_id,sentence_dict[sentence_id].strip())
# Out:
# Number of documents 36
# Number of sentences 1435
#
# 0 1321
#
# 0/10 05) Upon consultation between the Chin State Government and the Chin National Front, it is agreed to form an independent Chin human rights committee.

# %%
from spacy.lang.en.stop_words import STOP_WORDS

nlp_sm = spacy.load("en_core_web_sm")
nlp_sm.vocab["‘s"].is_stop = False

def sanitize_entity(text,nlp):
    clean_list = []
    doc = nlp(text, disable=['ner', 'parser'])
    for token in doc:
        if token.text != '’s' and nlp.vocab[token.text].is_stop == True:
            continue
        clean_list.append(token.text.strip())
    return clean_list


org_list = []
org_list.append('ORG')
org_list.append('GPE')
org_list.append('LOC')
org_list.append('PERSON')

print(colored('doc_id','blue'),'\t',colored('sentence_number','blue'),'\t','entity type','\t','entity')
print('')
for sentence_id,sentence_text in sentence_dict.items():
    sentence_doc = nlp_sm(sentence_text)
    entities = [(i.text,i.label_) for i in sentence_doc.ents if i.label_ in org_list]
    for _,entity_data in enumerate(entities):
        entity = ' '.join(sanitize_entity(entity_data[0],nlp_sm))
        
        # Just using IDs here but could be translated in document names and sentence_id values
        # used to sentence text from dictionaries
        doc_id = sentence_id.split('/')[0]
        sentence_number = sentence_id.split('/')[1]
        
        print(colored(doc_id,'blue'),'\t',colored(sentence_number,'blue'),'\t',entity_data[1],'\t',entity)

        print()
# Out:
# doc_id 	 sentence_number 	 entity type 	 entity
#
# 0 	 0 	 ORG 	 CNF - Govt Agreements
#
# 0 	 0 	 ORG 	 Chinland Guardian
#
# 0 	 0 	 ORG 	 Chin National ( CNF
#
# 0 	 0 	 ORG 	 Peace Committee Burma
#
# 0 	 0 	 GPE 	 Rangoon
#
# 0 	 1 	 ORG 	 Chin National Union
#
# 0 	 1 	 ORG 	 Peace Working Committee
#
# 0 	 1 	 ORG 	 Peace Talks
#
# 0 	 1 	 ORG 	 Union Burma
#
# 0 	 1 	 ORG 	 Chin National
#
# 0 	 1 	 ORG 	 Union Peace Working Committee
#
# 0 	 1 	 ORG 	 Union
#
# 0 	 1 	 ORG 	 Panglong
#
# 0 	 1 	 ORG 	 Chin National Peace Negotiating Team
#
# 0 	 1 	 ORG 	 Chin State Government
#
# 0 	 1 	 GPE 	 Hakha
#
# 0 	 1 	 GPE 	 Chin State
#
# 0 	 1 	 ORG 	 Chin National
#
# 0 	 1 	 ORG 	 Chin State Government
#
# 0 	 1 	 GPE 	 Chin State
#
# 0 	 1 	 ORG 	 Tranquility
#
# 0 	 2 	 ORG 	 Chin National
#
# 0 	 2 	 ORG 	 Non - disintegration
#
# 0 	 2 	 ORG 	 Union
#
# 0 	 2 	 ORG 	 National Solidarity Perpetuation Sovereignty
#
# 0 	 3 	 ORG 	 Chin National
#
# 0 	 3 	 ORG 	 Union Peace Working Committee
#
# 0 	 3 	 ORG 	 Tranquility Committee
#
# 0 	 3 	 ORG 	 Peace Facilitating Committee
#
# 0 	 4 	 ORG 	 Union Burma
#
# 0 	 4 	 ORG 	 Panglong Agreement
#
# 0 	 4 	 ORG 	 Kachin Hill Tribes Regulation
#
# 0 	 4 	 ORG 	 Government Burma Act
#
# 0 	 5 	 GPE 	 Burma
#
# 0 	 5 	 ORG 	 Panglong Conference
#
# 0 	 5 	 PERSON 	 Aung San
#
# 0 	 6 	 ORG 	 Government Chin State
#
# 0 	 7 	 ORG 	 Government Chin State
#
# 0 	 7 	 ORG 	 Chin Special Division
#
# 0 	 7 	 GPE 	 Chin State
#
# 0 	 8 	 ORG 	 Environment
#
# 0 	 8 	 ORG 	 Chin National
#
# 0 	 8 	 ORG 	 Unlawful Association Act
#
# 0 	 8 	 ORG 	 Chin National
#
# 0 	 8 	 ORG 	 Union Government
#
# 0 	 10 	 ORG 	 Chin State Government
#
# 0 	 10 	 ORG 	 Chin National
#
# 0 	 10 	 PERSON 	 Chin
#
# 0 	 11 	 ORG 	 National Human Rights Commission
#
# 0 	 11 	 ORG 	 Chin State Government
#
# 0 	 11 	 ORG 	 Chin National
#
# 0 	 13 	 GPE 	 Chin State
#
# 0 	 15 	 ORG 	 Chin State
#
# 0 	 17 	 ORG 	 Union Burma
#
# 0 	 17 	 ORG 	 Burma Army
#
# 0 	 17 	 GPE 	 Burma
#
# 0 	 19 	 ORG 	 Union Peace Working Committee
#
# 0 	 19 	 ORG 	 Chin National Chin National Army
#
# 0 	 19 	 GPE 	 Thantlang Township
#
# 0 	 19 	 GPE 	 Vanzang
#
# 0 	 19 	 ORG 	 Lungding
#
# 0 	 19 	 GPE 	 Belhar
#
# 0 	 19 	 GPE 	 Lulpilung Village Tracts
#
# 0 	 19 	 GPE 	 Tedim Township
#
# 0 	 21 	 ORG 	 Burma Army
#
# 0 	 21 	 ORG 	 Chin National Army
#
# 0 	 23 	 ORG 	 Chin National Army
#
# 0 	 23 	 ORG 	 Burma Army
#
# 0 	 23 	 ORG 	 Battalion
#
# 0 	 25 	 ORG 	 Chin National
#
# 0 	 27 	 PERSON 	 Chin
#
# 0 	 27 	 ORG 	 Chin National
#
# 0 	 27 	 ORG 	 Chin National Army
#
# 0 	 27 	 ORG 	 Non Governmental Organizations
#
# 0 	 27 	 ORG 	 Union Government
#
# 0 	 29 	 ORG 	 Union Government
#
# 0 	 29 	 ORG 	 Chin National
#
# 0 	 30 	 ORG 	 Chin National
#
# 0 	 30 	 ORG 	 International Non- Governmental Organizations
#
# 0 	 32 	 ORG 	 Chin State Government
#
# 0 	 32 	 ORG 	 Chin National
#
# 0 	 32 	 ORG 	 Chin National
#
# 0 	 32 	 ORG 	 Union Government
#
# 0 	 32 	 ORG 	 Chin State Government
#
# 0 	 35 	 ORG 	 Chin National
#
# 0 	 35 	 ORG 	 Union Government
#
# 0 	 35 	 ORG 	 Chin State Government
#
# 0 	 35 	 ORG 	 Community Radio
#
# 0 	 35 	 PERSON 	 Chin
#
# 0 	 35 	 PERSON 	 Chins
#
# 0 	 35 	 PERSON 	 Chin
#
# 0 	 37 	 ORG 	 Chin National
#
# 0 	 37 	 GPE 	 Chin State
#
# 0 	 39 	 ORG 	 Chin National
#
# 0 	 39 	 ORG 	 Chin State
#
# 0 	 41 	 ORG 	 Chin State Union Government
#
# 0 	 43 	 GPE 	 Chin State
#
# 0 	 43 	 GPE 	 Tonzang Township
#
# 0 	 43 	 LOC 	 Paletwa Township
#
# 0 	 45 	 ORG 	 Chin National
#
# 0 	 45 	 PERSON 	 Chin
#
# 0 	 49 	 ORG 	 Social Cultural Matters
#
# 0 	 50 	 ORG 	 Union Government
#
# 0 	 50 	 GPE 	 Chin State
#
# 0 	 52 	 PERSON 	 Chin
#
# 0 	 54 	 GPE 	 Burma
#
# 0 	 54 	 ORG 	 Union Government
#
# 0 	 54 	 ORG 	 Chin State Government
#
# 0 	 54 	 ORG 	 Chin National
#
# 0 	 62 	 ORG 	 Chin National
#
# 0 	 62 	 ORG 	 Chin State
#
# 0 	 64 	 PERSON 	 Chin
#
# 0 	 64 	 GPE 	 Chin State
#
# 0 	 64 	 ORG 	 Union Government
#
# 0 	 64 	 ORG 	 Chin State Government
#
# 0 	 64 	 ORG 	 Chin National
#
# 0 	 64 	 GPE 	 Naypyidaw
#
# 0 	 64 	 GPE 	 Yangon
#
# 0 	 64 	 ORG 	 Mandalay
#
# 0 	 64 	 ORG 	 Kalay
#
# 0 	 64 	 PERSON 	 Sittwe
#
# 0 	 64 	 PERSON 	 Seih
#
# 1 	 0 	 GPE 	 Republic Union Myanmar
#
# 1 	 0 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 0 	 ORG 	 Government Republic Union Myanmar
#
# 1 	 0 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 2 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 4 	 ORG 	 Panglong
#
# 1 	 5 	 ORG 	 Reach
#
# 1 	 5 	 GPE 	 Republic Union Myanmar
#
# 1 	 6 	 PERSON 	 c. Discuss
#
# 1 	 6 	 PERSON 	 Pyidaungsu Tatmadaw
#
# 1 	 7 	 GPE 	 Republic Union Myanmar
#
# 1 	 10 	 GPE 	 Republic Union Myanmar
#
# 1 	 15 	 GPE 	 Republic Union Myanmar
#
# 1 	 17 	 GPE 	 Republic Union Myanmar
#
# 1 	 17 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 18 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 22 	 GPE 	 Republic Union Myanmar
#
# 1 	 22 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 23 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 23 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 23 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 25 	 PERSON 	 Tatmadaw
#
# 1 	 27 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 27 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 29 	 PERSON 	 Tatmadaw
#
# 1 	 31 	 PERSON 	 c. Avoid
#
# 1 	 35 	 ORG 	 Government Republic Union Myanmar
#
# 1 	 43 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 45 	 PERSON 	 Tatmadaw
#
# 1 	 45 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 48 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 52 	 PERSON 	 Tatmadaw
#
# 1 	 55 	 PERSON 	 Tatmadaw
#
# 1 	 56 	 ORG 	 Avoid
#
# 1 	 57 	 PERSON 	 c. Avoid
#
# 1 	 66 	 ORG 	 healthcare
#
# 1 	 77 	 GPE 	 Republic Union Myanmar
#
# 1 	 77 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 77 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 77 	 PERSON 	 Internally Displaced Persons
#
# 1 	 77 	 ORG 	 Government Republic Union Myanmar
#
# 1 	 82 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 83 	 ORG 	 Nationwide Ceasefire Agreement Joint Implementation Coordination Meeting
#
# 1 	 83 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 83 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 83 	 ORG 	 Union Peace - Making Work Committee
#
# 1 	 83 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 84 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 85 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 87 	 ORG 	 Nationwide Ceasefire Agreement Joint Implementation Coordination Meeting
#
# 1 	 88 	 ORG 	 Nationwide Ceasefire Agreement Joint Implementation Coordination Meeting
#
# 1 	 89 	 PERSON 	 Internally Displaced Persons
#
# 1 	 91 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 93 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 95 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 1 	 95 	 ORG 	 Committee
#
# 1 	 96 	 ORG 	 Liaison Offices
#
# 1 	 97 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 101 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 103 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 105 	 GPE 	 Republic Union Myanmar Government
#
# 1 	 105 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 105 	 PERSON 	 a. Signing
#
# 1 	 105 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 106 	 ORG 	 “ Framework Political Dialogue
#
# 1 	 106 	 ORG 	 Government Republic Union Myanmar
#
# 1 	 106 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 107 	 ORG 	 Political Dialogue
#
# 1 	 110 	 GPE 	 Pyidaungsu Hluttaw
#
# 1 	 113 	 GPE 	 Republic Union Myanmar Government
#
# 1 	 113 	 ORG 	 Ethnic Armed  Organizations
#
# 1 	 114 	 ORG 	 Joint Monitoring Committee
#
# 1 	 114 	 ORG 	 Union Peace Dialogue Joint Committee
#
# 1 	 116 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 120 	 ORG 	 Hluttaws
#
# 1 	 120 	 PERSON 	 Tatmadaw
#
# 1 	 120 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 121 	 ORG 	 Framework Political Dialogue
#
# 1 	 122 	 ORG 	 Political Dialogue
#
# 1 	 128 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 130 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 130 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 132 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 140 	 ORG 	 Extractive Industries Transparency Initiative
#
# 1 	 140 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 141 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 141 	 ORG 	 Ethnic Armed Organization
#
# 1 	 142 	 PERSON 	 Pyidaungsu Hluttaw
#
# 1 	 143 	 GPE 	 Pyidaungsu Hluttaw
#
# 1 	 147 	 GPE 	 Myanmar
#
# 1 	 148 	 GPE 	 Myanmar
#
# 1 	 151 	 ORG 	 Nationwide Ceasefire Agreement Joint Implementation Coordination Meetings
#
# 1 	 153 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 156 	 ORG 	 Nationwide Ceasefire Agreement Joint Implementation Coordination Meeting
#
# 1 	 161 	 ORG 	 Nationwide Ceasefire Agreement
#
# 1 	 161 	 GPE 	 Republic Union Myanmar
#
# 1 	 161 	 ORG 	 Ethnic Armed Organizations
#
# 1 	 162 	 ORG 	 Leaders Executive
#
# 1 	 162 	 ORG 	 Hluttaw
#
# 1 	 162 	 PERSON 	 Tatmadaw
#
# 1 	 168 	 ORG 	 JMC
#
# 1 	 168 	 ORG 	 CBO
#
# 1 	 169 	 ORG 	 Nationwide Ceasefire Coordination Team
#
# 1 	 169 	 ORG 	 NCCT
#
# 1 	 169 	 ORG 	 UPWC
#
# 2 	 0 	 ORG 	 Working Committee
#
# 2 	 0 	 ORG 	 FDA
#
# 2 	 0 	 ORG 	 NBF
#
# 2 	 0 	 ORG 	 NLD
#
# 2 	 0 	 ORG 	 NUP
#
# 2 	 0 	 ORG 	 UNA
#
# 2 	 0 	 ORG 	 UEC
#
# 2 	 0 	 GPE 	 Yangon
#
# 2 	 3 	 GPE 	 Republic Union Myanmar
#
# 2 	 8 	 ORG 	 CoC
#
# 2 	 8 	 GPE 	 Republic Union Myanmar
#
# 2 	 11 	 ORG 	 CoC
#
# 2 	 17 	 ORG 	 CoC
#
# 2 	 17 	 GPE 	 Republic Myanmar
#
# 2 	 18 	 LOC 	 Pyithu Hluttaw Law
#
# 2 	 18 	 PERSON 	 Amoytha Hluttaw Law
#
# 2 	 18 	 ORG 	 State
#
# 2 	 20 	 ORG 	 CoC
#
# 2 	 21 	 ORG 	 CoC
#
# 2 	 22 	 ORG 	 CoC
#
# 2 	 22 	 GPE 	 Republic Union Myanmar
#
# 2 	 23 	 ORG 	 CoC
#
# 2 	 23 	 GPE 	 Myanmar
#
# 2 	 26 	 ORG 	 CoC
#
# 2 	 39 	 ORG 	 Union Election Commission
#
# 2 	 45 	 GPE 	 Republic Union Myanmar
#
# 2 	 47 	 ORG 	 UEC
#
# 2 	 55 	 ORG 	 Party
#
# 2 	 55 	 ORG 	 Party
#
# 2 	 59 	 ORG 	 Political Parties Registration Law Chapter II
#
# 2 	 78 	 ORG 	 Myanmar Police Force
#
# 2 	 81 	 PERSON 	 Hluttaw Laws
#
# 2 	 81 	 PERSON 	 Chapter XIV
#
# 2 	 84 	 ORG 	 UEC
#
# 2 	 89 	 ORG 	 Electoral Management Body
#
# 2 	 89 	 ORG 	 Union Election Commission
#
# 2 	 97 	 ORG 	 Party
#
# 2 	 116 	 LOC 	 Hluttaw Election
#
# 2 	 116 	 ORG 	 Chapter XIII
#
# 2 	 117 	 ORG 	 CoC
#
# 2 	 119 	 ORG 	 State
#
# 2 	 124 	 ORG 	 Gender
#
# 2 	 132 	 ORG 	 CoC
#
# 2 	 133 	 ORG 	 Party
#
# 2 	 135 	 ORG 	 CoC
#
# 2 	 138 	 ORG 	 CoC
#
# 2 	 138 	 ORG 	 UEC
#
# 2 	 140 	 ORG 	 Committee
#
# 2 	 140 	 ORG 	 Committee
#
# 2 	 142 	 ORG 	 CoC Monitoring Committee
#
# 2 	 143 	 ORG 	 Committee
#
# 2 	 145 	 ORG 	 CoC
#
# 2 	 147 	 ORG 	 CoC
#
# 2 	 147 	 ORG 	 CoC
#
# 2 	 147 	 ORG 	 CoC
#
# 3 	 0 	 ORG 	 Political Dialogue
#
# 3 	 0 	 ORG 	 Union Peace Dialogue Joint Committee
#
# 3 	 0 	 ORG 	 UPDJC
#
# 3 	 0 	 ORG 	 Parliament
#
# 3 	 0 	 ORG 	 Tatmadaw
#
# 3 	 0 	 ORG 	 Nationwide Ceasefire Agreement
#
# 3 	 0 	 ORG 	 NCA
#
# 3 	 0 	 GPE 	 Republic Union Myanmar
#
# 3 	 0 	 ORG 	 Ethnic Armed Organizations
#
# 3 	 0 	 GPE 	 Pyidaungsu Hluttaw
#
# 3 	 1 	 ORG 	 Political Dialogue
#
# 3 	 1 	 ORG 	 Union
#
# 3 	 2 	 ORG 	 Panglong
#
# 3 	 6 	 ORG 	 Framework Political Dialogue
#
# 3 	 10 	 ORG 	 Establish Union
#
# 3 	 11 	 ORG 	 democratic Union
#
# 3 	 13 	 ORG 	 Political Dialogue
#
# 3 	 13 	 ORG 	 Establish Union
#
# 3 	 14 	 ORG 	 Panglong
#
# 3 	 17 	 GPE 	 Republic Union Myanmar
#
# 3 	 18 	 ORG 	 Pyidaungsu Tatmadaw
#
# 3 	 19 	 GPE 	 Republic Union Myanmar
#
# 3 	 21 	 GPE 	 Republic Union Myanmar
#
# 3 	 24 	 GPE 	 Republic Union Myanmar
#
# 3 	 28 	 ORG 	 Nationwide Ceasefire Agreement
#
# 3 	 28 	 ORG 	 Political Dialogue
#
# 3 	 29 	 ORG 	 Union Peace Conference
#
# 3 	 31 	 GPE 	 Pyidaungsu Hluttaw
#
# 3 	 33 	 ORG 	 Union Peace Dialogue Joint Committee
#
# 3 	 33 	 ORG 	 UPDJC
#
# 3 	 34 	 ORG 	 National Political Dialogue
#
# 3 	 35 	 ORG 	 Working Committees
#
# 3 	 35 	 ORG 	 UPDJC
#
# 3 	 37 	 PERSON 	 Tatmadaw
#
# 3 	 42 	 ORG 	 Working Committees
#
# 3 	 42 	 ORG 	 Union Peace Conference
#
# 3 	 44 	 ORG 	 Nationwide Ceasefire Agreement
#
# 3 	 44 	 ORG 	 Political Dialogue
#
# 3 	 44 	 ORG 	 Union Peace Conference
#
# 3 	 45 	 PERSON 	 Tatmadaw
#
# 3 	 51 	 ORG 	 Union Peace Conference
#
# 3 	 53 	 ORG 	 Working Committees
#
# 3 	 54 	 ORG 	 Working Committee
#
# 3 	 56 	 ORG 	 UPDJC
#
# 3 	 56 	 ORG 	 Working Committee
#
# 3 	 58 	 ORG 	 UPDJC
#
# 3 	 58 	 ORG 	 Union Peace Conference
#
# 3 	 58 	 ORG 	 Union Peace
#
# 3 	 62 	 ORG 	 Union Peace Conference
#
# 3 	 64 	 ORG 	 UPDJC
#
# 3 	 66 	 ORG 	 Nationwide Ceasefire Agreement
#
# 3 	 66 	 ORG 	 Political Dialogue
#
# 3 	 75 	 ORG 	 UPDJC
#
# 3 	 92 	 PERSON 	 Chapter
#
# 3 	 92 	 ORG 	 Political Dialogue
#
# 3 	 92 	 ORG 	 Nationwide Ceasefire Agreement
#
# 3 	 94 	 ORG 	 Working Committee
#
# 3 	 96 	 ORG 	 Union Peace Conference
#
# 3 	 96 	 ORG 	 Working Committees
#
# 3 	 96 	 ORG 	 Union
#
# 3 	 98 	 ORG 	 Union Peace Conference
#
# 3 	 99 	 ORG 	 Chapter 7 Organization Political Dialogue
#
# 3 	 99 	 ORG 	 Peace Dialogue Joint Committee
#
# 3 	 99 	 ORG 	 UPDJC
#
# 3 	 99 	 ORG 	 UPDJC
#
# 3 	 99 	 ORG 	 Nationwide Ceasefire Agreement
#
# 3 	 99 	 ORG 	 NCA
#
# 3 	 101 	 ORG 	 UPDJC
#
# 3 	 101 	 PERSON 	 Tatmadaw
#
# 3 	 101 	 ORG 	 NCA
#
# 3 	 103 	 ORG 	 Responsibilities  7.2.1
#
# 3 	 104 	 ORG 	 UPDJC
#
# 3 	 106 	 ORG 	 UPDJC
#
# 3 	 106 	 ORG 	 NCA
#
# 3 	 108 	 ORG 	 UPDJC
#
# 3 	 108 	 GPE 	 Pyidaungsu Hluttaw
#
# 3 	 110 	 ORG 	 UPDJC
#
# 3 	 110 	 ORG 	 Working Committees
#
# 3 	 111 	 PERSON 	 Tatmadaw
#
# 3 	 112 	 ORG 	 UPDJC
#
# 3 	 112 	 ORG 	 Secretariat
#
# 3 	 113 	 ORG 	 UPDJC
#
# 3 	 114 	 ORG 	 Secretariat
#
# 3 	 114 	 ORG 	 UPDJC
#
# 3 	 115 	 ORG 	 Topics
#
# 3 	 115 	 ORG 	 Working Committees
#
# 3 	 118 	 ORG 	 Working Committees
#
# 3 	 120 	 ORG 	 Working Committees
#
# 3 	 120 	 ORG 	 Union Peace Conference
#
# 3 	 122 	 ORG 	 Working Committees
#
# 3 	 122 	 ORG 	 Secretariat
#
# 3 	 124 	 ORG 	 Working Committees
#
# 3 	 126 	 ORG 	 Working Committee
#
# 3 	 126 	 ORG 	 Working Committees
#
# 3 	 126 	 ORG 	 UPDJC
#
# 3 	 127 	 PERSON 	 Technical Teams
#
# 3 	 128 	 ORG 	 UPDJC
#
# 3 	 128 	 ORG 	 Technical Team
#
# 3 	 129 	 ORG 	 UPDJC
#
# 3 	 129 	 ORG 	 Union Peace Conference
#
# 3 	 130 	 ORG 	 UPDJC
#
# 3 	 131 	 ORG 	 Union Republic Myanmar
#
# 3 	 132 	 ORG 	 Panglong
#
# 3 	 141 	 GPE 	 Pyidaungsu Hluttaw
#
# 3 	 143 	 ORG 	 Pyidaungsu Accord
#
# 3 	 143 	 ORG 	 Parliament
#
# 3 	 150 	 ORG 	 Political Dialogue
#
# 3 	 150 	 ORG 	 UPDJC
#
# 3 	 150 	 ORG 	 Working Committees
#
# 3 	 153 	 ORG 	 Political Dialogue
#
# 3 	 153 	 ORG 	 Framework Political Dialogue
#
# 3 	 153 	 ORG 	 UPDJC
#
# 3 	 154 	 ORG 	 Nationwide Ceasefire Agreement
#
# 4 	 0 	 PERSON 	 Conduct
#
# 4 	 0 	 GPE 	 Accordance
#
# 4 	 0 	 ORG 	 NCA
#
# 4 	 1 	 ORG 	 Government Burma
#
# 4 	 1 	 ORG 	 NCA
#
# 4 	 2 	 ORG 	 Joint Monitoring Committee
#
# 4 	 9 	 ORG 	 NCA
#
# 4 	 9 	 GPE 	 Tamataw
#
# 4 	 14 	 ORG 	 NCA
#
# 4 	 16 	 GPE 	 Tamataw
#
# 4 	 28 	 ORG 	 healthcare
#
# 4 	 35 	 GPE 	 Ceasefire
#
# 4 	 40 	 ORG 	 NCA
#
# 4 	 40 	 ORG 	 Security  Sectors Reforms
#
# 4 	 47 	 ORG 	 NCA
#
# 4 	 47 	 ORG 	 NCA
#
# 4 	 50 	 GPE 	 Tamataw
#
# 4 	 54 	 GPE 	 Tamataw
#
# 4 	 56 	 ORG 	 NCA
#
# 4 	 57 	 GPE 	 Tamataw
#
# 4 	 61 	 ORG 	 JICM
#
# 4 	 62 	 GPE 	 Naypyitaw
#
# 4 	 62 	 ORG 	 NCA
#
# 4 	 65 	 PERSON 	 Gen. Ya Pyit
#
# 4 	 67 	 PERSON 	 U Khin Maung Soe  Union
#
# 4 	 69 	 PERSON 	 Gen. Ye Aung  Chief
#
# 4 	 71 	 PERSON 	 Tun Tun Naung
#
# 4 	 74 	 PERSON 	 Aung Kyaw Zaw
#
# 4 	 77 	 GPE 	 Naung
#
# 4 	 79 	 ORG 	 U Myint Soe  Retired Lt
#
# 4 	 82 	 PERSON 	 Aung Soe
#
# 4 	 82 	 ORG 	 Ministry Interior
#
# 4 	 84 	 ORG 	 Ministry Defense ( Army
#
# 4 	 85 	 PERSON 	 Min Zaw
#
# 4 	 85 	 ORG 	 MPC
#
# 4 	 87 	 PERSON 	 Gen. Saw Isaac Poe  Quartermaster General
#
# 4 	 87 	 ORG 	 KNLA  Permanent Central Committee
#
# 4 	 87 	 ORG 	 KNU
#
# 4 	 89 	 PERSON 	 Gen. Saw Nay Soe Mya  Adjutant General
#
# 4 	 89 	 ORG 	 KNU / KNLA
#
# 4 	 90 	 PERSON 	 Shwe Kah
#
# 4 	 90 	 ORG 	 CNF
#
# 4 	 92 	 PERSON 	 Saw Kyaw Htay
#
# 4 	 92 	 PERSON 	 Liaison Officer
#
# 4 	 95 	 PERSON 	 Khun Aung Mang  PNLO
#
# 4 	 96 	 PERSON 	 Salai Yaw Aung  ABSDF
#
# 4 	 100 	 PERSON 	 Hsaung Han
#
# 4 	 102 	 PERSON 	 Sai Liang
#
# 5 	 0 	 ORG 	 Joint Monitoring Committee Guideline
#
# 5 	 1 	 ORG 	 Nationwide Ceasefire Agreement
#
# 5 	 1 	 ORG 	 NCA
#
# 5 	 1 	 GPE 	 Naypyitaw
#
# 5 	 2 	 ORG 	 Ceasefire Joint Monitoring Committee
#
# 5 	 2 	 ORG 	 NCA
#
# 5 	 7 	 ORG 	 Ceasefire Joint Monitoring Committee
#
# 5 	 10 	 ORG 	 NCA
#
# 5 	 11 	 ORG 	 NCA
#
# 5 	 14 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 5 	 14 	 ORG 	 JMC - U
#
# 5 	 15 	 ORG 	 NCA
#
# 5 	 15 	 ORG 	 Union Level Joint Ceasefire Monitoring Committee
#
# 5 	 15 	 ORG 	 Union Level Joint Ceasefire Monitoring Committee
#
# 5 	 15 	 ORG 	 JMC - U
#
# 5 	 17 	 ORG 	 JMC - U
#
# 5 	 18 	 PERSON 	 Chairperson
#
# 5 	 23 	 ORG 	 Committee
#
# 5 	 23 	 ORG 	 JICM
#
# 5 	 25 	 ORG 	 JMC - U
#
# 5 	 25 	 ORG 	 NCA
#
# 5 	 26 	 ORG 	 JMC
#
# 5 	 27 	 ORG 	 JMC - U
#
# 5 	 29 	 PERSON 	 JICM
#
# 5 	 31 	 ORG 	 JMC - U
#
# 5 	 38 	 ORG 	 JMC - U
#
# 5 	 38 	 ORG 	 JICM
#
# 5 	 40 	 ORG 	 JMC - U
#
# 5 	 40 	 ORG 	 JICM
#
# 5 	 41 	 ORG 	 JMC
#
# 5 	 41 	 ORG 	 International Community
#
# 5 	 43 	 ORG 	 JMC - U
#
# 5 	 43 	 ORG 	 JICM
#
# 5 	 45 	 ORG 	 JMC
#
# 5 	 46 	 ORG 	 JMC - U
#
# 5 	 48 	 ORG 	 JMC - U
#
# 5 	 48 	 ORG 	 JMC - S
#
# 5 	 48 	 ORG 	 JICM
#
# 5 	 50 	 ORG 	 JMC - U
#
# 5 	 50 	 ORG 	 Local Level Joint Ceasefire Monitoring Committee
#
# 5 	 50 	 ORG 	 JMC - L
#
# 5 	 50 	 ORG 	 JMC - S.
#
# 5 	 51 	 ORG 	 JMC - S
#
# 5 	 51 	 ORG 	 JMC
#
# 5 	 51 	 ORG 	 JMC - U
#
# 5 	 51 	 ORG 	 JMC - S.
#
# 5 	 52 	 ORG 	 JMC
#
# 5 	 52 	 ORG 	 JMC - S.
#
# 5 	 53 	 ORG 	 JMC - U
#
# 5 	 53 	 ORG 	 Verification Teams
#
# 5 	 55 	 ORG 	 JMC - U
#
# 5 	 57 	 ORG 	 JMC - U
#
# 5 	 58 	 ORG 	 JMC
#
# 5 	 60 	 ORG 	 JMC - U
#
# 5 	 62 	 ORG 	 NCA
#
# 5 	 62 	 ORG 	 JMC
#
# 5 	 64 	 ORG 	 JMC - U
#
# 5 	 66 	 ORG 	 JMC - U
#
# 5 	 66 	 ORG 	 Verification Teams
#
# 5 	 68 	 ORG 	 JMC - U
#
# 5 	 68 	 ORG 	 JMC - S.
#
# 5 	 69 	 ORG 	 JMC - U
#
# 5 	 72 	 ORG 	 JMC - S
#
# 5 	 72 	 ORG 	 JMC - U.  Meetings Resolutions
#
# 5 	 73 	 ORG 	 JMC - U
#
# 5 	 75 	 ORG 	 JMC - U
#
# 5 	 76 	 ORG 	 JMC - U
#
# 5 	 78 	 ORG 	 JMC - U
#
# 5 	 82 	 ORG 	 JMC - U
#
# 5 	 82 	 ORG 	 JICM
#
# 5 	 84 	 ORG 	 JMC - U
#
# 5 	 86 	 ORG 	 JMC - U
#
# 5 	 87 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 5 	 87 	 ORG 	 JMC - S
#
# 5 	 88 	 ORG 	 JMC - S
#
# 5 	 88 	 ORG 	 JMC - U
#
# 5 	 90 	 ORG 	 JMC - S
#
# 5 	 93 	 ORG 	 Civilian
#
# 5 	 94 	 ORG 	 Ministry Security
#
# 5 	 94 	 ORG 	 State / Division
#
# 5 	 94 	 ORG 	 State / Division
#
# 5 	 94 	 PERSON 	 EAOs
#
# 5 	 94 	 ORG 	 ee ) EAOs
#
# 5 	 94 	 PERSON 	 EAOs
#
# 5 	 94 	 ORG 	 Civilians
#
# 5 	 96 	 ORG 	 General Staff
#
# 5 	 96 	 ORG 	 JMC - S
#
# 5 	 96 	 ORG 	 JMC - U.
#
# 5 	 97 	 ORG 	 JMC - S.
#
# 5 	 97 	 ORG 	 JMC - S
#
# 5 	 98 	 ORG 	 JMC - S
#
# 5 	 98 	 ORG 	 NCA
#
# 5 	 100 	 ORG 	 JMC - S
#
# 5 	 100 	 ORG 	 NCA
#
# 5 	 102 	 ORG 	 JMC - S
#
# 5 	 104 	 ORG 	 JMC - S
#
# 5 	 107 	 ORG 	 JMC - S
#
# 5 	 109 	 ORG 	 JMC - S
#
# 5 	 109 	 ORG 	 Local Level Joint Ceasefire Monitoring Committee
#
# 5 	 109 	 ORG 	 JMC - L
#
# 5 	 109 	 ORG 	 JMC - L
#
# 5 	 111 	 ORG 	 JMC - S
#
# 5 	 111 	 ORG 	 JMC - U.
#
# 5 	 112 	 ORG 	 JMC - S
#
# 5 	 112 	 ORG 	 JMC - U
#
# 5 	 114 	 ORG 	 JMC - S
#
# 5 	 114 	 ORG 	 Local Level Joint Ceasefire Monitoring Committee
#
# 5 	 114 	 ORG 	 JMC - L
#
# 5 	 114 	 ORG 	 JICM
#
# 5 	 114 	 ORG 	 JMC - U.
#
# 5 	 115 	 ORG 	 NCA
#
# 5 	 115 	 ORG 	 JMC
#
# 5 	 115 	 ORG 	 JMC - S
#
# 5 	 116 	 ORG 	 JMC - S
#
# 5 	 116 	 ORG 	 JMC - S
#
# 5 	 116 	 ORG 	 JMC - U.
#
# 5 	 117 	 ORG 	 JMC - S
#
# 5 	 119 	 ORG 	 JMC - S
#
# 5 	 119 	 ORG 	 JMC - S
#
# 5 	 119 	 ORG 	 Verification Team
#
# 5 	 120 	 ORG 	 Joint Ceasefire Monitoring
#
# 5 	 122 	 ORG 	 JMC - S
#
# 5 	 122 	 ORG 	 JMC - L
#
# 5 	 124 	 ORG 	 JMC - S
#
# 5 	 126 	 ORG 	 JMC - S
#
# 5 	 128 	 ORG 	 JMC - S
#
# 5 	 128 	 ORG 	 Verification Team
#
# 5 	 130 	 ORG 	 JMC - S
#
# 5 	 130 	 ORG 	 JMC - L
#
# 5 	 130 	 ORG 	 JMC - U.
#
# 5 	 131 	 ORG 	 JMC - S
#
# 5 	 131 	 ORG 	 JMC - U
#
# 5 	 131 	 ORG 	 NCA
#
# 5 	 132 	 ORG 	 JMC - S
#
# 5 	 133 	 ORG 	 JMC - S
#
# 5 	 135 	 ORG 	 JMC - S
#
# 5 	 136 	 ORG 	 JMC - S
#
# 5 	 136 	 ORG 	 JMC - S
#
# 5 	 138 	 ORG 	 JMC - S
#
# 5 	 142 	 ORG 	 JMC - S
#
# 5 	 142 	 ORG 	 JMC - U.
#
# 5 	 143 	 ORG 	 JMC - S
#
# 5 	 145 	 ORG 	 JMC - S
#
# 5 	 146 	 ORG 	 JMC - L
#
# 5 	 147 	 ORG 	 JMC - L
#
# 5 	 147 	 ORG 	 JMC - S.
#
# 5 	 147 	 ORG 	 Joint Ceasefire Monitoring Committee
#
# 5 	 147 	 ORG 	 JMC - L
#
# 5 	 149 	 ORG 	 JMC - L
#
# 5 	 150 	 ORG 	 Civilian
#
# 5 	 150 	 ORG 	 Township General Administration
#
# 5 	 150 	 ORG 	 Civilian
#
# 5 	 150 	 GPE 	 Tamataw
#
# 5 	 150 	 ORG 	 JMC - L
#
# 5 	 150 	 ORG 	 JMC - S.
#
# 5 	 150 	 ORG 	 JMC - L
#
# 5 	 151 	 ORG 	 JMC - L.  Responsibilities JMC - L
#
# 5 	 152 	 ORG 	 JMC - S
#
# 5 	 152 	 ORG 	 JMC - L
#
# 5 	 154 	 ORG 	 JMC - L
#
# 5 	 154 	 ORG 	 JMC - S
#
# 5 	 156 	 ORG 	 JMC - L
#
# 5 	 156 	 ORG 	 JMC - S.
#
# 5 	 157 	 ORG 	 JMC - L
#
# 5 	 157 	 ORG 	 JMC
#
# 5 	 159 	 ORG 	 JMC - L
#
# 5 	 159 	 ORG 	 JMC - S
#
# 5 	 162 	 ORG 	 JMC - L
#
# 5 	 164 	 ORG 	 JMC - L
#
# 5 	 166 	 ORG 	 JMC - L
#
# 5 	 166 	 ORG 	 Verification Team
#
# 5 	 168 	 ORG 	 JMC - L
#
# 5 	 168 	 ORG 	 JMC - S
#
# 5 	 170 	 ORG 	 JMC - L
#
# 5 	 172 	 ORG 	 JMC - L
#
# 5 	 172 	 ORG 	 Verification Team
#
# 5 	 173 	 ORG 	 JMC - L
#
# 5 	 174 	 ORG 	 JMC - L
#
# 5 	 176 	 ORG 	 JMC - S
#
# 5 	 179 	 ORG 	 JMC - S
#
# 5 	 180 	 ORG 	 Tenure Review
#
# 5 	 181 	 ORG 	 JMC - U
#
# 5 	 182 	 ORG 	 JMC - S
#
# 5 	 184 	 ORG 	 JMC - S
#
# 5 	 185 	 ORG 	 Verification Teams  Formation
#
# 5 	 186 	 ORG 	 JMC
#
# 5 	 186 	 ORG 	 JMC - U
#
# 5 	 186 	 ORG 	 JMC - S
#
# 5 	 186 	 ORG 	 Verification Team
#
# 5 	 187 	 ORG 	 Verification Team
#
# 5 	 187 	 ORG 	 JMC - L
#
# 5 	 188 	 ORG 	 JMC - U
#
# 5 	 188 	 ORG 	 JMC - S
#
# 5 	 188 	 ORG 	 JMC
#
# 5 	 188 	 ORG 	 JMC
#
# 5 	 189 	 ORG 	 Verification Team ’s
#
# 5 	 189 	 ORG 	 JMC - L
#
# 5 	 189 	 ORG 	 JMC
#
# 5 	 190 	 ORG 	 JMC
#
# 5 	 190 	 ORG 	 Verification Team
#
# 5 	 194 	 ORG 	 Verification Team
#
# 5 	 194 	 ORG 	 JMC
#
# 5 	 195 	 ORG 	 JMC
#
# 5 	 196 	 ORG 	 Verification Team
#
# 5 	 197 	 ORG 	 Verification Team
#
# 5 	 198 	 ORG 	 JMC
#
# 5 	 199 	 ORG 	 JMC
#
# 5 	 199 	 ORG 	 Verification Team
#
# 5 	 200 	 ORG 	 JMC
#
# 5 	 201 	 ORG 	 H
#
# 5 	 202 	 ORG 	 Verification Team
#
# 5 	 202 	 ORG 	 Team ’s
#
# 5 	 203 	 ORG 	 JMC - L
#
# 5 	 203 	 ORG 	 CSO
#
# 5 	 205 	 ORG 	 NCA
#
# 5 	 205 	 ORG 	 JMC - L
#
# 5 	 206 	 ORG 	 JMC - S
#
# 5 	 207 	 ORG 	 JMC
#
# 5 	 209 	 ORG 	 JMC
#
# 5 	 211 	 ORG 	 JMC
#
# 5 	 212 	 ORG 	 JMC
#
# 5 	 214 	 ORG 	 JMC
#
# 5 	 215 	 ORG 	 JMC
#
# 5 	 216 	 ORG 	 JMC
#
# 5 	 218 	 ORG 	 JMC
#
# 5 	 220 	 ORG 	 JMC
#
# 5 	 220 	 ORG 	 JMC
#
# 5 	 220 	 ORG 	 JMC
#
# 5 	 222 	 ORG 	 JMC
#
# 5 	 224 	 ORG 	 JMC
#
# 5 	 226 	 ORG 	 JMC
#
# 5 	 226 	 ORG 	 JMC
#
# 5 	 226 	 PERSON 	 JICM
#
# 6 	 0 	 ORG 	 Work Committee
#
# 6 	 0 	 ORG 	 ABSDF Union
#
# 6 	 4 	 ORG 	 ABSDF
#
# 6 	 5 	 ORG 	 ABSDF
#
# 6 	 6 	 ORG 	 ABSDF
#
# 6 	 9 	 ORG 	 Kalay
#
# 6 	 9 	 GPE 	 Payathonsu
#
# 6 	 9 	 ORG 	 ABSDF
#
# 7 	 0 	 ORG 	 Working Committee
#
# 7 	 0 	 ORG 	 Karenni National Progressive Party
#
# 7 	 0 	 ORG 	 KNPP
#
# 7 	 1 	 ORG 	 KNPP
#
# 7 	 1 	 ORG 	 Union
#
# 7 	 1 	 PERSON 	 U Aung Min
#
# 7 	 1 	 ORG 	 KNPP Khu Oo Reh
#
# 7 	 3 	 GPE 	 Kayah State
#
# 7 	 3 	 ORG 	 KNPP
#
# 7 	 4 	 ORG 	 TOR
#
# 7 	 5 	 GPE 	 Kayah State
#
# 7 	 5 	 GPE 	 New Village Project
#
# 7 	 10 	 ORG 	 KNPP
#
# 8 	 0 	 ORG 	 CNF - Government Ceasefire Agreement
#
# 8 	 0 	 ORG 	 Chin National
#
# 8 	 0 	 GPE 	 Myanmar
#
# 8 	 1 	 ORG 	 Chin National
#
# 8 	 1 	 ORG 	 Chin National Union
#
# 8 	 1 	 ORG 	 Hakha
#
# 8 	 1 	 GPE 	 Chin State
#
# 8 	 1 	 ORG 	 CNF
#
# 8 	 1 	 ORG 	 Peace Team
#
# 8 	 2 	 ORG 	 Ceasefire  Union
#
# 8 	 2 	 ORG 	 Peace Team
#
# 8 	 2 	 ORG 	 Chin State Government
#
# 8 	 2 	 ORG 	 Chin National Peace Team
#
# 8 	 4 	 GPE 	 Accordance
#
# 8 	 4 	 ORG 	 Chin National
#
# 8 	 4 	 ORG 	 Chin National Army
#
# 8 	 4 	 ORG 	 Chin National Chin State / Union Government
#
# 8 	 4 	 GPE 	 Tlangpi
#
# 8 	 4 	 PERSON 	 Dawn
#
# 8 	 4 	 PERSON 	 Zangtlang Village
#
# 8 	 4 	 GPE 	 Thantlang Township
#
# 8 	 4 	 PERSON 	 Zampi
#
# 8 	 4 	 PERSON 	 Bukphir Village
#
# 8 	 4 	 GPE 	 Tedim Township
#
# 8 	 5 	 ORG 	 CNF
#
# 8 	 5 	 GPE 	 Kung Pyin
#
# 8 	 5 	 GPE 	 Pathiantlang Village
#
# 8 	 5 	 ORG 	 Western Command
#
# 8 	 6 	 ORG 	 CNF
#
# 8 	 6 	 GPE 	 Thantlang Township ’s Belhar
#
# 8 	 6 	 GPE 	 Vanzang
#
# 8 	 6 	 GPE 	 Lungding Village
#
# 8 	 6 	 GPE 	 Lulpilung
#
# 8 	 7 	 GPE 	 Tedim Township ’s Dampi
#
# 8 	 7 	 PERSON 	 Tui Dial Village
#
# 8 	 8 	 LOC 	 Shweletwa Village
#
# 8 	 8 	 PERSON 	 Ra Kan Village
#
# 8 	 9 	 ORG 	 Myanmar Army
#
# 8 	 9 	 ORG 	 Myanmar Police Force
#
# 8 	 9 	 ORG 	 Chin National Chin National Army
#
# 8 	 9 	 ORG 	 Liaison Offices
#
# 8 	 11 	 ORG 	 Liaison Office
#
# 8 	 12 	 ORG 	 Chin National
#
# 8 	 12 	 ORG 	 Chin National Army
#
# 8 	 12 	 ORG 	 Union Burma
#
# 8 	 12 	 ORG 	 Union Myanmar
#
# 8 	 13 	 ORG 	 Myanmar Army
#
# 8 	 14 	 ORG 	 Liaison Offices
#
# 8 	 14 	 GPE 	 Thanglang
#
# 8 	 14 	 GPE 	 Tedim
#
# 8 	 14 	 ORG 	 Matupi Towns
#
# 8 	 16 	 ORG 	 CNF
#
# 8 	 16 	 ORG 	 Central Committee
#
# 8 	 16 	 ORG 	 CNF
#
# 8 	 17 	 ORG 	 Chin State Government
#
# 8 	 18 	 ORG 	 Chin State Government
#
# 8 	 19 	 ORG 	 State
#
# 8 	 19 	 ORG 	 Union
#
# 8 	 20 	 ORG 	 Union
#
# 8 	 20 	 ORG 	 Panglong
#
# 8 	 21 	 ORG 	 Matters International Agreements
#
# 8 	 21 	 ORG 	 Government Union Mynamar
#
# 8 	 22 	 ORG 	 Chin National
#
# 8 	 22 	 ORG 	 Union Myanmar
#
# 8 	 22 	 ORG 	 ‘ National Causes ’
#
# 8 	 23 	 ORG 	 Matters Humanitarian Organizations
#
# 8 	 23 	 ORG 	 Union Ministries
#
# 8 	 23 	 ORG 	 Chin State
#
# 8 	 23 	 ORG 	 CNF
#
# 8 	 24 	 PERSON 	 Chin State
#
# 8 	 24 	 ORG 	 CNF
#
# 8 	 24 	 ORG 	 Memorandum Understanding (
#
# 8 	 24 	 ORG 	 Chin State Government
#
# 8 	 24 	 ORG 	 Union Government
#
# 8 	 25 	 PERSON 	 Chin
#
# 8 	 26 	 ORG 	 State
#
# 8 	 26 	 GPE 	 District
#
# 8 	 26 	 PERSON 	 Village
#
# 8 	 26 	 ORG 	 Government ’s Order
#
# 8 	 28 	 GPE 	 Visas
#
# 8 	 28 	 ORG 	 Chin
#
# 8 	 28 	 ORG 	 CNF
#
# 8 	 28 	 ORG 	 Union Myanmar
#
# 8 	 29 	 ORG 	 Chin National Day
#
# 8 	 31 	 ORG 	 Chin National Army
#
# 8 	 33 	 ORG 	 Peace Team
#
# 8 	 33 	 ORG 	 CNF
#
# 8 	 33 	 ORG 	 CNA
#
# 8 	 34 	 ORG 	 Chin State
#
# 8 	 34 	 ORG 	 CNF
#
# 8 	 35 	 ORG 	 CNF
#
# 8 	 35 	 ORG 	 National Identity Card
#
# 8 	 35 	 ORG 	 Immigration Department
#
# 8 	 36 	 ORG 	 CNF
#
# 8 	 37 	 ORG 	 Chin National
#
# 8 	 37 	 ORG 	 Chin National Army
#
# 8 	 45 	 PERSON 	 Ceasefire Monitoring Body
#
# 8 	 46 	 ORG 	 Chin Peace Tranquility Committee
#
# 8 	 47 	 ORG 	 Ceasefire Monitoring Body
#
# 8 	 47 	 ORG 	 Union Government
#
# 8 	 47 	 ORG 	 Myanmar Army
#
# 8 	 47 	 ORG 	 Myanmar Police Force
#
# 8 	 47 	 ORG 	 Chin National
#
# 8 	 47 	 ORG 	 Chin National Army
#
# 8 	 50 	 ORG 	 Chin State Border Areas Security Affairs
#
# 8 	 50 	 PERSON 	 Liaison
#
# 8 	 50 	 ORG 	 Chin National
#
# 8 	 50 	 ORG 	 Chin National Army
#
# 8 	 50 	 ORG 	 Chin National Army
#
# 8 	 50 	 ORG 	 Myanmar Army Police Force
#
# 8 	 50 	 ORG 	 Chin Peace Monitoring Body
#
# 8 	 51 	 PERSON 	 Liaison Officer
#
# 8 	 51 	 ORG 	 Chin National / Chin National Army
#
# 8 	 51 	 ORG 	 Myanmar Army
#
# 8 	 51 	 ORG 	 Ceasefire Monitoring Body
#
# 8 	 53 	 ORG 	 CNF
#
# 8 	 53 	 ORG 	 Chin State Government
#
# 8 	 53 	 ORG 	 Northwestern Commands
#
# 8 	 53 	 ORG 	 Myanmar Army
#
# 8 	 53 	 ORG 	 Union Peace Team Crisis Mediating Body
#
# 8 	 54 	 ORG 	 Union Guesthouse
#
# 8 	 54 	 GPE 	 Hakha
#
# 8 	 54 	 GPE 	 Chin State
#
# 8 	 55 	 ORG 	 Union
#
# 9 	 0 	 PERSON 	 Kalo Htoo Baw
#
# 9 	 0 	 PERSON 	 Karen State
#
# 9 	 1 	 PERSON 	 Aung Lwin
#
# 9 	 1 	 PERSON 	 Kalo Htoo Baw U Saw Mu Shay
#
# 9 	 1 	 ORG 	 Unofficial Translation
#
# 9 	 1 	 PERSON 	 Kalo Htoo Baw
#
# 9 	 1 	 GPE 	 Karen State
#
# 9 	 2 	 PERSON 	 Kalo Htoo Baw
#
# 9 	 2 	 GPE 	 Sonsee
#
# 9 	 3 	 ORG 	 Kaloh Htoo Baw
#
# 9 	 3 	 ORG 	 Myawaddy
#
# 9 	 5 	 PERSON 	 Kaloh Htoo Baw
#
# 9 	 6 	 PERSON 	 Gen Saw Lar Pwe
#
# 10 	 0 	 ORG 	 KNU
#
# 10 	 0 	 ORG 	 Burmese Government
#
# 10 	 0 	 ORG 	 KNU
#
# 10 	 0 	 PERSON 	 U Aung Min
#
# 10 	 1 	 ORG 	 KNU
#
# 10 	 2 	 ORG 	 KNU
#
# 10 	 3 	 ORG 	 KNU
#
# 10 	 3 	 ORG 	 KNU
#
# 10 	 4 	 ORG 	 KNU
#
# 10 	 5 	 ORG 	 KNU
#
# 11 	 0 	 PERSON 	 U Aung Thaung
#
# 11 	 0 	 PERSON 	 U Thein Zaw
#
# 11 	 0 	 ORG 	 U Win Tun
#
# 11 	 0 	 GPE 	 Special Region
#
# 11 	 0 	 PERSON 	 Sai Lin
#
# 11 	 0 	 PERSON 	 U San Pae
#
# 11 	 0 	 PERSON 	 U Kham Maung
#
# 11 	 0 	 LOC 	 Special Region
#
# 11 	 2 	 GPE 	 Kengtung
#
# 11 	 3 	 GPE 	 Special Region
#
# 11 	 4 	 GPE 	 Special Region
#
# 11 	 5 	 GPE 	 Special Region
#
# 11 	 6 	 GPE 	 Special Region
#
# 11 	 6 	 GPE 	 Republic Union Myanmar
#
# 11 	 6 	 GPE 	 Special Region
#
# 11 	 7 	 GPE 	 Republic Union Myanmar
#
# 11 	 8 	 ORG 	 State
#
# 11 	 8 	 ORG 	 State
#
# 11 	 8 	 GPE 	 Special Region
#
# 11 	 8 	 ORG 	 State
#
# 12 	 0 	 ORG 	 NMSP Government
#
# 12 	 0 	 ORG 	 Strand Hotel Mawlamyine
#
# 12 	 0 	 GPE 	 Mon State
#
# 12 	 0 	 ORG 	 Peacemaking Group
#
# 12 	 0 	 ORG 	 Union
#
# 12 	 0 	 PERSON 	 U Aung Min
#
# 12 	 0 	 ORG 	 Union
#
# 12 	 0 	 PERSON 	 U Soe Thein
#
# 12 	 0 	 ORG 	 Union
#
# 12 	 0 	 PERSON 	 U Zaw Min
#
# 12 	 0 	 ORG 	 Union
#
# 12 	 0 	 PERSON 	 U Win Tun
#
# 12 	 0 	 ORG 	 State
#
# 12 	 0 	 ORG 	 U Ohn Myint
#
# 12 	 0 	 ORG 	 South - East Command Maj - Gen Tin Maung Win
#
# 12 	 0 	 ORG 	 Mon State Security
#
# 12 	 0 	 PERSON 	 Col Htay Myint Aung
#
# 12 	 0 	 PERSON 	 Grade
#
# 12 	 0 	 ORG 	 Army ) Office
#
# 12 	 0 	 PERSON 	 Grade
#
# 12 	 0 	 GPE 	 Mon State
#
# 12 	 0 	 ORG 	 NMSP
#
# 12 	 0 	 PERSON 	 U Nai Rawsa
#
# 12 	 1 	 ORG 	 State
#
# 12 	 1 	 ORG 	 Col Htay Myint Aung
#
# 12 	 1 	 ORG 	 NMSP
#
# 12 	 1 	 ORG 	 NMSP CEC
#
# 12 	 1 	 PERSON 	 U Nai Talanyi
#
# 12 	 1 	 ORG 	 Union Ministers
#
# 12 	 1 	 ORG 	 U Soe Thein
#
# 12 	 1 	 ORG 	 U Zaw Min
#
# 12 	 1 	 ORG 	 U Win Tun
#
# 12 	 1 	 ORG 	 State
#
# 12 	 1 	 ORG 	 U Ohn Myint
#
# 12 	 3 	 ORG 	 Formation Union
#
# 12 	 7 	 ORG 	 NMSP
#
# 12 	 20 	 GPE 	 Mon State
#
# 12 	 21 	 ORG 	 New Mon State Party
#
# 12 	 24 	 ORG 	 Remark
#
# 12 	 25 	 ORG 	 U Nai Talanyi
#
# 12 	 26 	 PERSON 	 U Aung Min
#
# 12 	 26 	 PERSON 	 U Nai Rawsa
#
# 13 	 0 	 ORG 	 NSCN - K
#
# 13 	 0 	 PERSON 	 Kyi Naing
#
# 13 	 0 	 PERSON 	 Naga
#
# 13 	 0 	 ORG 	 NSCN
#
# 13 	 0 	 PERSON 	 Y Wantin Naga
#
# 13 	 0 	 ORG 	 Station Hall
#
# 13 	 0 	 GPE 	 Khamti
#
# 13 	 0 	 GPE 	 Sagaing Region
#
# 13 	 2 	 PERSON 	 Tatmadaw
#
# 13 	 2 	 ORG 	 NSCN
#
# 13 	 3 	 ORG 	 NSCN
#
# 13 	 3 	 GPE 	 Khamti
#
# 13 	 4 	 ORG 	 NSCN
#
# 13 	 5 	 ORG 	 NSCN
#
# 14 	 0 	 ORG 	 SSA - S Government Ceasefire Agreement
#
# 14 	 0 	 ORG 	 Group
#
# 14 	 0 	 GPE 	 Taunggyi
#
# 14 	 0 	 GPE 	 Shan State
#
# 14 	 12 	 PERSON 	 Liaison
#
# 14 	 12 	 GPE 	 Taunggyi
#
# 14 	 12 	 GPE 	 Kengtung
#
# 14 	 12 	 PERSON 	 Kholam
#
# 14 	 12 	 ORG 	 Tachilek
#
# 14 	 12 	 GPE 	 Mongton
#
# 14 	 17 	 ORG 	 Union Government
#
# 15 	 0 	 ORG 	 SSA - S Government 11
#
# 15 	 0 	 ORG 	 Union - Level
#
# 15 	 0 	 GPE 	 Taunggyi
#
# 15 	 0 	 GPE 	 Shan State
#
# 15 	 2 	 GPE 	 Homain
#
# 15 	 2 	 ORG 	 Mong Hta
#
# 15 	 6 	 ORG 	 SSA
#
# 15 	 8 	 GPE 	 Homain
#
# 15 	 8 	 ORG 	 Mong Hta
#
# 15 	 12 	 ORG 	 SSA - S
#
# 15 	 12 	 GPE 	 Taunggyi
#
# 15 	 12 	 GPE 	 Kholam
#
# 15 	 12 	 GPE 	 Kengtung
#
# 15 	 12 	 PERSON 	 Mong Hsat
#
# 15 	 12 	 PERSON 	 Tachileik
#
# 15 	 12 	 ORG 	 Muse
#
# 15 	 12 	 ORG 	 Nanhkan
#
# 15 	 13 	 ORG 	 SSA
#
# 16 	 0 	 ORG 	 SSA - S Government
#
# 16 	 0 	 ORG 	 Union Peacemaking Work
#
# 16 	 1 	 ORG 	 Restoration Council Shan State / Shan State Army
#
# 16 	 1 	 GPE 	 Kengtung
#
# 16 	 1 	 GPE 	 Shan State
#
# 16 	 2 	 ORG 	 Shan Herald
#
# 16 	 4 	 ORG 	 UPWC
#
# 16 	 6 	 PERSON 	 Shan
#
# 16 	 8 	 ORG 	 Tai Freedom
#
# 17 	 0 	 ORG 	 SSPP / SSA - N Government  Preliminary Peace
#
# 17 	 0 	 ORG 	 Shan State Progressive Party
#
# 17 	 0 	 ORG 	 SSPP)/ Shan State Army
#
# 17 	 0 	 GPE 	 Taunggyi
#
# 17 	 0 	 LOC 	 South
#
# 17 	 1 	 PERSON 	 Taungtha Township
#
# 17 	 1 	 PERSON 	 U Aung Thaung
#
# 17 	 1 	 PERSON 	 Myitkyina Township
#
# 17 	 1 	 PERSON 	 U Thein Zaw
#
# 17 	 1 	 ORG 	 U Ohn Myint
#
# 17 	 1 	 PERSON 	 U Win Tun
#
# 17 	 1 	 ORG 	 Shan State
#
# 17 	 1 	 PERSON 	 U Sao Aung Myat
#
# 17 	 1 	 PERSON 	 Kayan Township
#
# 17 	 1 	 PERSON 	 U Maung Maung Thein
#
# 17 	 1 	 ORG 	 North - East Command Maj - Gen Aung Kyaw Zaw
#
# 17 	 1 	 ORG 	 Central East Command
#
# 17 	 1 	 PERSON 	 Maj - Gen Zaw Win
#
# 17 	 1 	 PERSON 	 U Soe Tint
#
# 17 	 1 	 PERSON 	 Aung Thu
#
# 17 	 2 	 ORG 	 Shan State Progressive Party
#
# 17 	 2 	 ORG 	 State Army
#
# 17 	 2 	 ORG 	 Party Central Committee
#
# 17 	 2 	 PERSON 	 Sao Khay Tai
#
# 17 	 2 	 PERSON 	 Sao Khin Min
#
# 17 	 2 	 GPE 	 Sao Khun Hsai
#
# 17 	 2 	 GPE 	 Sao Khay Maung
#
# 17 	 2 	 GPE 	 Sao Kyaw Hla
#
# 17 	 2 	 GPE 	 Sao Htin Mein
#
# 17 	 2 	 PERSON 	 Sao Laung Khay
#
# 17 	 2 	 GPE 	 Sao Naw Leik
#
# 17 	 4 	 ORG 	 Shan State Minster Security
#
# 17 	 4 	 PERSON 	 Aung Thu
#
# 17 	 4 	 PERSON 	 Grade
#
# 17 	 4 	 ORG 	 North - East Command
#
# 17 	 4 	 ORG 	 General Staff
#
# 17 	 4 	 PERSON 	 Grade
#
# 17 	 4 	 ORG 	 Central East Command
#
# 17 	 4 	 ORG 	 Department Progress Border Areas National Races
#
# 17 	 4 	 ORG 	 State Advocate General
#
# 17 	 4 	 ORG 	 SSPP / Shan State Army Sao Khun Hsai
#
# 17 	 4 	 GPE 	 Sao Khay Maung
#
# 17 	 4 	 GPE 	 Sao Kyaw
#
# 17 	 4 	 PERSON 	 Sao Htin Mein
#
# 17 	 6 	 PERSON 	 Tatmadaw
#
# 17 	 6 	 ORG 	 SSPP / Shan State Army
#
# 17 	 7 	 ORG 	 SSPP / Shan State Army
#
# 17 	 7 	 GPE 	 Wanhai
#
# 17 	 8 	 GPE 	 Taunggyi
#
# 17 	 8 	 GPE 	 Lashio
#
# 17 	 8 	 GPE 	 Kholan
#
# 17 	 12 	 PERSON 	 U Aung Thaung
#
# 17 	 12 	 ORG 	 Shan State Progressive
#
# 17 	 12 	 ORG 	 Party/ Shan State Army
#
# 17 	 12 	 PERSON 	 Sao Khay Tai
#
# 17 	 14 	 GPE 	 Shan State
#
# 17 	 14 	 ORG 	 Shan State Progressive Party
#
# 17 	 14 	 GPE 	 Taunggyi
#
# 17 	 15 	 ORG 	 Panglong
#
# 17 	 16 	 ORG 	 Shan State Progressive Party
#
# 17 	 19 	 PERSON 	 U Aung Thaung
#
# 17 	 19 	 PERSON 	 U Thein Zaw
#
# 17 	 19 	 ORG 	 Sky Net TV
#
# 17 	 19 	 ORG 	 SSPP / Shan State Army
#
# 17 	 19 	 PERSON 	 Sao Khay Tai
#
# 17 	 19 	 GPE 	 Sao Khun Hsai
#
# 18 	 0 	 ORG 	 UWSA Government
#
# 18 	 0 	 ORG 	 Group
#
# 18 	 0 	 PERSON 	 U Aung Thaung
#
# 18 	 0 	 ORG 	 Peacemaking Group
#
# 18 	 0 	 ORG 	 U Shauk Min Lyan
#
# 18 	 0 	 GPE 	 Pansang
#
# 18 	 1 	 GPE 	 Lashio
#
# 18 	 5 	 GPE 	 Republic Union Myanmar
#
# 18 	 6 	 GPE 	 Republic Union Myanmar
#
# 18 	 7 	 ORG 	 State
#
# 18 	 7 	 ORG 	 State
#
# 19 	 0 	 ORG 	 KNU Press Release
#
# 19 	 0 	 ORG 	 KNU Delegation
#
# 19 	 0 	 ORG 	 KNU Delegation
#
# 19 	 0 	 GPE 	 Rangoon
#
# 19 	 1 	 PERSON 	 U Aung Min
#
# 19 	 1 	 GPE 	 Republic Union Burma
#
# 19 	 1 	 GPE 	 Myanmar
#
# 19 	 1 	 PERSON 	 Naw Zipporah Sein
#
# 19 	 1 	 ORG 	 KNU
#
# 19 	 17 	 ORG 	 KNU
#
# 19 	 17 	 GPE 	 Myanmar
#
# 19 	 17 	 GPE 	 Burma
#
# 19 	 17 	 GPE 	 Myanmar
#
# 20 	 0 	 PERSON 	 Kalo Htoo Baw
#
# 20 	 0 	 PERSON 	 Taungtha Township Pyithu Hluttaw Representative
#
# 20 	 0 	 PERSON 	 U Aung Thaung
#
# 20 	 0 	 PERSON 	 Kalo Htoo Baw
#
# 20 	 0 	 PERSON 	 U Saw Lah Pwe
#
# 20 	 3 	 ORG 	 Kayin State Peace Making Group
#
# 20 	 3 	 PERSON 	 Kalo Htoo Baw
#
# 20 	 5 	 GPE 	 Karen State
#
# 20 	 5 	 GPE 	 Republic Union Myanmar
#
# 20 	 8 	 ORG 	 Non - disintegration
#
# 20 	 8 	 ORG 	 Union
#
# 20 	 8 	 ORG 	 National Solidarity Perpetuation Sovereignty
#
# 20 	 10 	 PERSON 	 Kalo Htoo Baw
#
# 20 	 10 	 GPE 	 Sukali
#
# 21 	 0 	 ORG 	 PNLO
#
# 21 	 0 	 ORG 	 Myanmar Government
#
# 21 	 0 	 ORG 	 National Liberation Organization Myanmar Government
#
# 21 	 4 	 GPE 	 Taunggyi
#
# 21 	 4 	 ORG 	 Hsihseng
#
# 21 	 4 	 ORG 	 Maukmai
#
# 22 	 0 	 ORG 	 PNLO
#
# 22 	 0 	 ORG 	 UPWC
#
# 22 	 0 	 GPE 	 Myanmar
#
# 22 	 0 	 GPE 	 Yangon
#
# 22 	 1 	 ORG 	 PNLO
#
# 22 	 2 	 ORG 	 PNLO
#
# 22 	 6 	 ORG 	 Liaison Office Economic
#
# 22 	 7 	 GPE 	 Taunggyi
#
# 22 	 8 	 GPE 	 Hsee
#
# 22 	 8 	 ORG 	 Mauk Mae
#
# 22 	 8 	 GPE 	 Tha Htone
#
# 22 	 10 	 ORG 	 UPWC
#
# 22 	 10 	 ORG 	 PNLO
#
# 22 	 11 	 ORG 	 Anti - Narcotics Development
#
# 22 	 11 	 ORG 	 PNLO
#
# 22 	 11 	 PERSON 	 Ka Du Gyi
#
# 22 	 11 	 PERSON 	 Mae Aww
#
# 22 	 11 	 ORG 	 PNLO
#
# 22 	 11 	 ORG 	 PNLO
#
# 22 	 11 	 ORG 	 State
#
# 22 	 11 	 ORG 	 healthcare
#
# 22 	 12 	 ORG 	 PNLO
#
# 22 	 16 	 ORG 	 PNLO
#
# 22 	 16 	 ORG 	 UPWC
#
# 22 	 16 	 ORG 	 Remark
#
# 22 	 16 	 ORG 	 PNLO
#
# 22 	 16 	 ORG 	 UNFC
#
# 22 	 18 	 ORG 	 PNLO
#
# 22 	 18 	 PERSON 	 Khun Okkar
#
# 22 	 18 	 ORG 	 U Khun Myint Htun
#
# 22 	 18 	 PERSON 	 Khin Mg Soe
#
# 23 	 0 	 ORG 	 Kachin Independence Organization
#
# 23 	 0 	 GPE 	 Myitkyina City
#
# 23 	 0 	 ORG 	 Kachin State
#
# 23 	 0 	 GPE 	 Myanmar
#
# 23 	 0 	 ORG 	 KIO
#
# 23 	 2 	 ORG 	 Monitoring Committees
#
# 23 	 5 	 GPE 	 Myitkyina
#
# 23 	 5 	 ORG 	 KIO
#
# 23 	 8 	 GPE 	 Myanmar
#
# 24 	 0 	 ORG 	 NDAA
#
# 24 	 1 	 ORG 	 NDAA
#
# 24 	 1 	 GPE 	 Rangoon
#
# 24 	 1 	 GPE 	 Taunggyi
#
# 24 	 1 	 ORG 	 Tachilek
#
# 24 	 1 	 ORG 	 Mandalay
#
# 24 	 3 	 ORG 	 NDAA
#
# 24 	 3 	 LOC 	 Eastern Shan
#
# 24 	 5 	 ORG 	 NDAA
#
# 24 	 9 	 ORG 	 NDAA
#
# 24 	 11 	 ORG 	 NDAA
#
# 24 	 17 	 ORG 	 NDAA
#
# 24 	 19 	 ORG 	 NGOS
#
# 24 	 19 	 ORG 	 U.N.
#
# 24 	 21 	 ORG 	 NDAA
#
# 24 	 23 	 ORG 	 NDAA
#
# 24 	 27 	 ORG 	 NDAA
#
# 24 	 31 	 ORG 	 NDAA
#
# 24 	 31 	 GPE 	 Republic Union Myanmar
#
# 24 	 33 	 ORG 	 NDAA
#
# 24 	 33 	 ORG 	 NDAA
#
# 24 	 33 	 ORG 	 NDAA
#
# 24 	 35 	 ORG 	 NDAA
#
# 24 	 37 	 ORG 	 NDAA
#
# 24 	 39 	 ORG 	 NDAA
#
# 25 	 0 	 ORG 	 National Reconciliation
#
# 25 	 0 	 ORG 	 Deed Commitment Peace National Reconciliation
#
# 25 	 0 	 GPE 	 Myanmar
#
# 25 	 3 	 ORG 	 Union
#
# 25 	 3 	 ORG 	 Panglong
#
# 25 	 3 	 ORG 	 Political Dialogue
#
# 25 	 5 	 ORG 	 Nationwide Ceasefire Agreement
#
# 25 	 10 	 ORG 	 Political Dialogue
#
# 25 	 10 	 ORG 	 Nationwide Ceasefire Agreement
#
# 25 	 10 	 ORG 	 General Elections
#
# 25 	 10 	 ORG 	 Political Dialogue
#
# 25 	 13 	 ORG 	 Deed Commitment Peace National Reconciliation
#
# 26 	 0 	 ORG 	 SSA - S
#
# 26 	 1 	 ORG 	 UNODC
#
# 26 	 1 	 PERSON 	 Mongnai
#
# 26 	 1 	 PERSON 	 Mongpan
#
# 26 	 2 	 ORG 	 UNODC
#
# 26 	 5 	 ORG 	 UNODC
#
# 26 	 6 	 ORG 	 UNODC
#
# 26 	 8 	 ORG 	 CCDAC
#
# 26 	 8 	 ORG 	 Shan State Police Force
#
# 26 	 9 	 ORG 	 CCDAC - UNODC
#
# 26 	 9 	 ORG 	 UNODC
#
# 26 	 9 	 ORG 	 UN Office
#
# 26 	 9 	 ORG 	 Central Committee Drug Abuse Control
#
# 26 	 9 	 ORG 	 UNODC
#
# 27 	 3 	 ORG 	 Genuine
#
# 27 	 4 	 ORG 	 Formation Union Armed Forces
#
# 27 	 8 	 ORG 	 Achieving
#
# 27 	 12 	 ORG 	 Aims & Objectives
#
# 27 	 16 	 ORG 	 Federal Union
#
# 27 	 21 	 GPE 	 Panlong
#
# 27 	 21 	 PERSON 	 Pyidaungsu Accord
#
# 27 	 22 	 ORG 	 Nationalities
#
# 27 	 23 	 PERSON 	 Pyidaungsu Accord
#
# 27 	 40 	 ORG 	 Illegal Association
#
# 27 	 52 	 ORG 	 “ Common Agreement
#
# 27 	 55 	 PERSON 	 U Twan Zaw
#
# 27 	 55 	 ORG 	 Arakan Liberation Party Arakan National Council
#
# 27 	 56 	 ORG 	 U Tun Mrat Naing
#
# 27 	 57 	 PERSON 	 Pu Zin Cun Commander
#
# 27 	 57 	 ORG 	 General Arakan Army Chin National
#
# 27 	 58 	 PERSON 	 Saw Mo Shay
#
# 27 	 59 	 PERSON 	 Koon Abel Tweed
#
# 27 	 59 	 ORG 	 Democratic Karen Benevolent Army
#
# 27 	 62 	 PERSON 	 Saw Kyaw Dah
#
# 27 	 62 	 ORG 	 Karen National Union Foreign & Public Relations Department
#
# 27 	 62 	 ORG 	 KNU / KNLA Peace Council 9
#
# 27 	 63 	 PERSON 	 Kya Khunsa
#
# 27 	 64 	 ORG 	 Lahu Democratic Union Myanmar National Democratic Alliance Army
#
# 28 	 1 	 ORG 	 Union
#
# 28 	 1 	 PERSON 	 Panglong
#
# 28 	 1 	 GPE 	 Republic Union Myanmar
#
# 28 	 1 	 ORG 	 Union
#
# 28 	 1 	 PERSON 	 Century Panglong
#
# 28 	 3 	 ORG 	 Union Peace Dialogue Joint Committee
#
# 28 	 3 	 ORG 	 UPDJC
#
# 28 	 5 	 ORG 	 Nationwide Ceasefire Agreement
#
# 28 	 6 	 PERSON 	 Century Panglong
#
# 28 	 6 	 ORG 	 Nationwide Ceasefire Agreement Section 20
#
# 28 	 8 	 PERSON 	 Tin Myo Win  Representative
#
# 28 	 8 	 ORG 	 Government Group
#
# 28 	 9 	 PERSON 	 Win Myint  Representative
#
# 28 	 9 	 ORG 	 Hluttaw Group  3
#
# 28 	 10 	 ORG 	 Tatmadaw Group  4
#
# 28 	 11 	 PERSON 	 Lian Hmung Sakhong
#
# 28 	 11 	 ORG 	 Ethnic Armed Organization Group  5
#
# 28 	 12 	 ORG 	 U Thu Wai  Representative
#
# 28 	 12 	 ORG 	 Political Parties Group  Page
#
# 28 	 12 	 ORG 	 Kyaw Win  Relevant Representative
#
# 28 	 12 	 ORG 	 Government Group
#
# 28 	 12 	 ORG 	 Ethnic Armed Organization Group  U Zein Khan Ram  Ethnic Representative Political Parties Group
#
# 28 	 12 	 ORG 	 Political Parties Group  Union
#
# 28 	 12 	 PERSON 	 III Addendum
#
# 28 	 13 	 GPE 	 Republic Union Myanmar
#
# 28 	 13 	 ORG 	 Union
#
# 28 	 13 	 ORG 	 Union
#
# 28 	 13 	 ORG 	 Panglong
#
# 28 	 23 	 GPE 	 Republic Union Myanmar
#
# 28 	 25 	 ORG 	 NCA
#
# 28 	 27 	 ORG 	 UPDJC
#
# 28 	 27 	 ORG 	 JMC
#
# 28 	 29 	 GPE 	 Republic Union Myanmar
#
# 28 	 32 	 ORG 	 NCA
#
# 28 	 35 	 GPE 	 Hluttaw
#
# 28 	 35 	 PERSON 	 Tatmadaw
#
# 28 	 35 	 ORG 	 NCA - S
#
# 28 	 36 	 ORG 	 NCA
#
# 28 	 37 	 ORG 	 NCA
#
# 28 	 39 	 ORG 	 NCA
#
# 28 	 41 	 ORG 	 NCA
#
# 28 	 41 	 ORG 	 NCA
#
# 28 	 41 	 ORG 	 UPDJC
#
# 28 	 43 	 ORG 	 UPDJC
#
# 28 	 43 	 PERSON 	 III Addendum
#
# 28 	 43 	 ORG 	 State
#
# 28 	 43 	 ORG 	 Establishment Union
#
# 28 	 44 	 ORG 	 Union
#
# 28 	 45 	 ORG 	 Implementing Union
#
# 28 	 47 	 ORG 	 NCA
#
# 28 	 47 	 PERSON 	 III Addendum
#
# 28 	 47 	 ORG 	 Union
#
# 28 	 47 	 PERSON 	 Panglong
#
# 28 	 47 	 GPE 	 Republic Union Myanmar
#
# 28 	 47 	 ORG 	 Union
#
# 28 	 51 	 ORG 	 Constitutional Tribunal
#
# 29 	 0 	 GPE 	 Lashio
#
# 29 	 4 	 GPE 	 Republic Union Myanmar
#
# 29 	 5 	 GPE 	 Republic Union Myanmar
#
# 29 	 6 	 ORG 	 State
#
# 29 	 6 	 ORG 	 State
#
# 29 	 6 	 ORG 	 State
#
# 30 	 0 	 ORG 	 Mongla Armed Group ( Special Region 4 - Northern Shan State
#
# 30 	 0 	 GPE 	 Kengtung
#
# 30 	 1 	 GPE 	 Special Region
#
# 30 	 2 	 GPE 	 Special Region
#
# 30 	 3 	 GPE 	 Special Region
#
# 30 	 4 	 GPE 	 Special Region
#
# 30 	 4 	 GPE 	 Republic Union Myanmar
#
# 30 	 4 	 GPE 	 Special Region
#
# 30 	 5 	 GPE 	 Republic Union Myanmar
#
# 30 	 6 	 ORG 	 State
#
# 30 	 6 	 ORG 	 State
#
# 30 	 6 	 GPE 	 Special Region
#
# 30 	 6 	 ORG 	 State
#
# 31 	 0 	 ORG 	 CNF Government
#
# 31 	 0 	 ORG 	 Chinland Guardian
#
# 31 	 0 	 GPE 	 Myanmar
#
# 31 	 0 	 ORG 	 Union Myanmar
#
# 31 	 0 	 ORG 	 Ethnic Affairs
#
# 31 	 0 	 ORG 	 Internal Peace Committee
#
# 31 	 0 	 ORG 	 People ’s Parliament
#
# 31 	 0 	 ORG 	 National Parliament
#
# 31 	 0 	 ORG 	 Union
#
# 31 	 0 	 PERSON 	 U Aung Min
#
# 31 	 0 	 ORG 	 Union Myanmar U Thein Sein
#
# 31 	 0 	 PERSON 	 Pu Zing Cung
#
# 31 	 0 	 ORG 	 Chin National
#
# 31 	 0 	 ORG 	 Joint General
#
# 31 	 0 	 PERSON 	 Sui Khar
#
# 31 	 0 	 GPE 	 Thailand
#
# 31 	 0 	 ORG 	 Chin National ’s
#
# 31 	 0 	 ORG 	 Central Executive Committee ’s
#
# 31 	 1 	 ORG 	 Chin National
#
# 31 	 2 	 ORG 	 Chin State Government
#
# 31 	 2 	 ORG 	 Chin National
#
# 31 	 3 	 ORG 	 Chin State Government
#
# 31 	 3 	 ORG 	 Chin National
#
# 31 	 3 	 ORG 	 Liaison Office
#
# 31 	 3 	 GPE 	 Thantlang
#
# 31 	 4 	 ORG 	 Liaison Offices
#
# 31 	 4 	 GPE 	 Tedim
#
# 31 	 4 	 GPE 	 Matupi
#
# 31 	 5 	 ORG 	 Chin National / Army
#
# 31 	 5 	 GPE 	 Thantlang Township :
#
# 31 	 5 	 GPE 	 Tlangpi Village Tract
#
# 31 	 5 	 GPE 	 Dawn Village Tract
#
# 31 	 5 	 PERSON 	 Zang Tlang Village Tract
#
# 31 	 6 	 GPE 	 Tedim Township ’s
#
# 31 	 6 	 PERSON 	 Bukphir Village
#
# 31 	 6 	 ORG 	 Paletwa Township ’s Kung Pin
#
# 31 	 6 	 GPE 	 Para
#
# 31 	 6 	 GPE 	 Pathiantlang Village
#
# 31 	 7 	 ORG 	 Chin State Government
#
# 31 	 7 	 ORG 	 Chin National
#
# 31 	 7 	 ORG 	 Chin National Chin National Army
#
# 31 	 8 	 ORG 	 Chin State Government
#
# 31 	 8 	 ORG 	 Chin National
#
# 31 	 8 	 ORG 	 Chin National
#
# 31 	 10 	 ORG 	 Chin State Government
#
# 31 	 10 	 ORG 	 Chin National
#
# 31 	 10 	 ORG 	 Chin National
#
# 31 	 10 	 ORG 	 Chin National Army
#
# 31 	 11 	 ORG 	 Chin State Government
#
# 31 	 11 	 ORG 	 Chin National
#
# 31 	 11 	 ORG 	 Non - Governmental Organizations
#
# 31 	 11 	 ORG 	 Union Myanmar
#
# 31 	 13 	 ORG 	 Chin State Government
#
# 31 	 13 	 ORG 	 Chin National
#
# 31 	 13 	 ORG 	 Chin National
#
# 31 	 13 	 LOC 	 Special Economic Zone
#
# 31 	 13 	 ORG 	 Union Myanmar
#
# 31 	 13 	 ORG 	 State
#
# 31 	 14 	 ORG 	 Chin State Government
#
# 31 	 14 	 ORG 	 Chin National
#
# 31 	 14 	 ORG 	 Chin National
#
# 31 	 14 	 ORG 	 Chin State Government
#
# 31 	 14 	 LOC 	 Chin State
#
# 31 	 15 	 ORG 	 Chin State Government
#
# 31 	 15 	 ORG 	 Chin National
#
# 31 	 15 	 GPE 	 Chin State
#
# 31 	 16 	 ORG 	 Chin State Government
#
# 31 	 16 	 ORG 	 Chin National
#
# 31 	 16 	 PERSON 	 Railway
#
# 31 	 16 	 PERSON 	 U Aung Min
#
# 31 	 16 	 ORG 	 Environment Forestry
#
# 31 	 16 	 PERSON 	 U Win Htun
#
# 31 	 16 	 PERSON 	 U Hung Ngai
#
# 31 	 16 	 ORG 	 Peace Tranquillity Committee
#
# 32 	 0 	 ORG 	 Shan State Progressive Party / Shan State Army
#
# 32 	 0 	 GPE 	 Shan State
#
# 32 	 0 	 ORG 	 Shan State Progressive Party
#
# 32 	 0 	 GPE 	 Taunggyi
#
# 32 	 1 	 ORG 	 Union
#
# 32 	 1 	 ORG 	 Panglong
#
# 32 	 2 	 ORG 	 Shan State Progressive Party
#
# 33 	 0 	 ORG 	 New Mon State Party
#
# 33 	 0 	 ORG 	 NMSP
#
# 33 	 0 	 ORG 	 NMSP
#
# 33 	 2 	 ORG 	 Formation Union
#
# 34 	 0 	 ORG 	 State
#
# 34 	 0 	 ORG 	 KNU
#
# 34 	 0 	 ORG 	 KNLA Peace Council
#
# 34 	 0 	 PERSON 	 Tatmadaw
#
# 34 	 0 	 ORG 	 KNU / KNLA Peace Council
#
# 34 	 1 	 ORG 	 KNU
#
# 34 	 1 	 ORG 	 KNLA Peace Council
#
# 34 	 1 	 PERSON 	 Mela
#
# 34 	 2 	 PERSON 	 Liaison
#
# 34 	 3 	 GPE 	 Phayathonzu
#
# 34 	 3 	 PERSON 	 Kawkareik
#
# 34 	 3 	 GPE 	 Mawtaung
#
# 34 	 3 	 GPE 	 Kawthoung
#
# 34 	 5 	 ORG 	 KNU
#
# 34 	 5 	 ORG 	 KNLA Peace Council
#
# 34 	 6 	 ORG 	 State
#
# 34 	 7 	 ORG 	 KNU
#
# 34 	 7 	 ORG 	 KNLA Peace Council
#
# 35 	 0 	 ORG 	 Rakhine State Government Peace - Making Group
#
# 35 	 0 	 ORG 	 Rakhine State Liberation Party
#
# 35 	 0 	 GPE 	 Sittway
#
# 35 	 0 	 PERSON 	 Tatmadaw
#
# 35 	 0 	 ORG 	 Rakhine State Liberation Party
#
# 35 	 1 	 ORG 	 Rakhine State Liberation Party
#
# 35 	 1 	 PERSON 	 Kyauktaw
#
# 35 	 2 	 ORG 	 Rakhine State Liberation Party
#
# 35 	 3 	 ORG 	 Peace Making Group
#
# 35 	 3 	 ORG 	 Union Government
#
# 35 	 3 	 ORG 	 Rakhine State Liberation Party
#
# 35 	 4 	 ORG 	 Rakhine State Peace Discussion Group
#
# 35 	 4 	 ORG 	 State Security
#
# 35 	 4 	 PERSON 	 Htein Lin
#
# 35 	 5 	 ORG 	 Rakhine State Liberation Party
#
# 35 	 5 	 ORG 	 Joint General

# %%
import pandas as pd

# %%
df=pd.DataFrame.from_dict(document_dict)

# %%
df1=df.transpose()

# %%
df1=df1.reset_index()

# %%
df2=df1.rename(columns={'index':'doc_id', 'name':'agreement_id'})

# %%
results=pd.read_csv('myanmar_results_ents.csv', sep='\t')

# %%
list(df2)
# Out:
# ['doc_id', 'agreement_id']

# %%
list(results)
# Out:
# ['doc_id ', ' sentence_number ', ' entity type ', ' entity']

# %%
res=results.rename(columns={'doc_id ': 'doc_id'})

# %%
res.dtypes
# Out:
# doc_id                int64
#  sentence_number      int64
#  entity type         object
#  entity              object
# dtype: object

# %%
df2.dtypes
# Out:
# doc_id          object
# agreement_id    object
# dtype: object

# %%
df2['doc_id']=df2['doc_id'].astype('int64')

# %%
df3=pd.merge(res, df2, on='doc_id', how='inner')

# %%
df3
# Out:
#       doc_id   sentence_number   entity type   \
# 0          0                  0          ORG
# 1          0                  0          ORG
# 2          0                  0          ORG
# 3          0                  0          ORG
# 4          0                  0          GPE
# ...      ...                ...           ...
# 1372      35                  4          ORG
# 1373      35                  4          ORG
# 1374      35                  4       PERSON
# 1375      35                  5          ORG
# 1376      35                  5          ORG
#
#                                      entity agreement_id
# 0                     CNF - Govt Agreements         1321
# 1                         Chinland Guardian         1321
# 2                       Chin National ( CNF         1321
# 3                     Peace Committee Burma         1321
# 4                                   Rangoon         1321
# ...                                     ...          ...
# 1372   Rakhine State Peace Discussion Group          776
# 1373                         State Security          776
# 1374                              Htein Lin          776
# 1375         Rakhine State Liberation Party          776
# 1376                          Joint General          776
#
# [1377 rows x 5 columns]

# %%
df3.to_csv('full_myanmar_entities.csv')
